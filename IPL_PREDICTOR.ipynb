# %%
import numpy as np
import pandas as pd

# %%
matches=pd.read_csv(r"C:\Users\Kale Ji\Downloads\matches.csv")
delivery=pd.read_csv(r"D:\Download\deliveries.csv")

# %%
matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
matches.shape
# Out:
# (1095, 20)

# %%
delivery.shape
# Out:
# (260920, 17)

# %%
total_score_df=delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
# Out:
# C:\Users\Kale Ji\AppData\Local\Temp\ipykernel_6344\2630719186.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_score_df=delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df.head()
# Out:
#    match_id  inning  total_runs
# 0    335982       1         222
# 1    335982       2          82
# 2    335983       1         240
# 3    335983       2         207
# 4    335984       1         129

# %%
total_score_df = total_score_df[total_score_df['inning'] == 1]
total_score_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 2       335983       1         240
# 4       335984       1         129
# 6       335985       1         165
# 8       335986       1         110
# ...        ...     ...         ...
# 2207   1426307       1         214
# 2209   1426309       1         159
# 2211   1426310       1         172
# 2213   1426311       1         175
# 2215   1426312       1         113
#
# [1095 rows x 3 columns]

# %%
total_score_df.head()
# Out:
#    match_id  inning  total_runs
# 0    335982       1         222
# 2    335983       1         240
# 4    335984       1         129
# 6    335985       1         165
# 8    335986       1         110

# %%
matches['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
matches['team2'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
matches_df=matches.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
teams=[
    'Mumbai Indians',
    'Chennai Super Kings',
    'Royal Challengers Bangalore',
    'Rajasthan Royals',
    'Sunrisers Hyderabad',
    'Gujarat Titans',
    'Lucknow Super Giants',
    'Delhi Capitals',
    'Punjab Kings',
    'Kolkata Knight Riders'
]

# %%
matches_df['team1']=matches_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
matches_df['team2']=matches_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')
matches_df['team1']=matches_df['team1'].str.replace('Kings XI Punjab','Punjab Kings')
matches_df['team2']=matches_df['team2'].str.replace('Kings XI Punjab','Punjab Kings')
matches_df['team1']=matches_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
matches_df['team2']=matches_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
matches_df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali                 Punjab Kings
# 2                            Feroz Shah Kotla               Delhi Capitals
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner  ...   result  \
# ...

# %%
matches_df.shape
# Out:
# (1095, 22)

# %%
matches_df=matches_df[matches_df['team1'].isin(teams)]

# %%
matches_df=matches_df[matches_df['team2'].isin(teams)]

# %%
matches_df.shape
# Out:
# (965, 22)

# %%
matches_df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali                 Punjab Kings
# 2                            Feroz Shah Kotla               Delhi Capitals
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner  ...   result  \
# ...

# %%
matches_df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'total_runs'],
#       dtype='object')

# %%
matches_df['method'].value_counts()
# Out:
# D/L    17
# Name: method, dtype: int64

# %%
dls=matches_df[matches_df['method']=="D/L"]

# %%
len(dls)
# Out:
# 17

# %%
matches_df=matches_df[['match_id','city','winner','total_runs']]

# %%
matches_df.head()
# Out:
#    match_id        city                       winner  total_runs
# 0    335982   Bangalore        Kolkata Knight Riders         222
# 1    335983  Chandigarh          Chennai Super Kings         240
# 2    335984       Delhi             Delhi Daredevils         129
# 3    335985      Mumbai  Royal Challengers Bangalore         165
# 4    335986     Kolkata        Kolkata Knight Riders         110

# %%
delivery_df=matches_df.merge(delivery,on='match_id')

# %%
delivery_df.head()
# Out:
#    match_id       city                 winner  total_runs_x  inning  \
# 0    335982  Bangalore  Kolkata Knight Riders           222       1
# 1    335982  Bangalore  Kolkata Knight Riders           222       1
# 2    335982  Bangalore  Kolkata Knight Riders           222       1
# 3    335982  Bangalore  Kolkata Knight Riders           222       1
# 4    335982  Bangalore  Kolkata Knight Riders           222       1
#
#             batting_team                 bowling_team  over  ball  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1  Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 3  Kolkata Knight Riders  Royal Challengers Bangalore     0     4
# 4  Kolkata Knight Riders  Royal Challengers Bangalore     0     5
#
#         batter   bowler  non_striker  batsman_runs  extra_runs  total_runs_y  \
# 0   SC Ganguly  P Kumar  BB McCullum             0           1             1
# ...

# %%
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df.shape
# Out:
# (111082, 20)

# %%
delivery_df['current_score']=delivery_df.groupby('match_id').cumsum()['total_runs_y']
# Out:
# C:\Users\Kale Ji\AppData\Local\Temp\ipykernel_6344\1213823236.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   delivery_df['current_score']=delivery_df.groupby('match_id').cumsum()['total_runs_y']

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... non_striker batsman_runs  extra_runs  total_runs_y  extras_type  \
# ...

# %%
delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... batsman_runs extra_runs  total_runs_y  extras_type  is_wicket  \
# ...

# %%
delivery_df['balls_left']=120-(delivery_df['over']*6+delivery_df['ball'])

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
# ...

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna(0)
delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x:x if x==0 else 1)
delivery_df['player_dismissed']=delivery_df['player_dismissed'].astype('int')

# %%
wickets=delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
# Out:
# C:\Users\Kale Ji\AppData\Local\Temp\ipykernel_6344\1035948897.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   wickets=delivery_df.groupby('match_id').cumsum()['player_dismissed'].values

# %%
delivery_df['wickets_left']=10-wickets

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... total_runs_y extras_type  is_wicket  player_dismissed  \
# ...

# %%
delivery_df['crr']=(delivery_df['current_score']*6)/(120-delivery_df['balls_left'])

# %%
delivery_df['rrr']=(delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
# ...

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(result,axis=1)

# %%
delivery_df=delivery_df[['batting_team','bowling_team','city','runs_left','total_runs_x','balls_left','wickets_left','crr','rrr','result']]

# %%
delivery_df.head()
# Out:
#                     batting_team           bowling_team       city  runs_left  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        221
# 125  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        220
# 126  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        220
# 127  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        219
# 128  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore        218
#
#      total_runs_x  balls_left  wickets_left  crr        rrr  result
# 124           222         119            10  6.0  11.142857       0
# 125           222         118            10  6.0  11.186441       0
# 126           222         117            10  4.0  11.282051       0
# 127           222         116            10  4.5  11.327586       0
# 128           222         115            10  4.8  11.373913       0

# %%
final_df=delivery_df

# %%
final_df.sample(final_df.shape[0])     #unorganising the ball by ball scheme of the dataframe
# Out:
#                        batting_team                 bowling_team       city  \
# 214604  Royal Challengers Bangalore          Sunrisers Hyderabad  Hyderabad
# 20694              Rajasthan Royals  Royal Challengers Bangalore  Centurion
# 97124              Rajasthan Royals               Mumbai Indians  Ahmedabad
# 70494                Mumbai Indians             Rajasthan Royals     Jaipur
# 61995              Delhi Daredevils              Deccan Chargers  Hyderabad
# ...                             ...                          ...        ...
# 200881             Rajasthan Royals                 Punjab Kings   Guwahati
# 88436           Chennai Super Kings               Mumbai Indians     Mumbai
# 26351               Deccan Chargers  Royal Challengers Bangalore  Centurion
# 181963               Gujarat Titans         Lucknow Super Giants     Mumbai
# 75488           Chennai Super Kings               Mumbai Indians     Mumbai
#
# ...

# %%
final_df.sample()
# Out:
#                     batting_team    bowling_team    city  runs_left  \
# 884  Royal Challengers Bangalore  Mumbai Indians  Mumbai         80
#
#      total_runs_x  balls_left  wickets_left  crr       rrr  result
# 884           165          52             7  7.5  9.230769       1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
final_df.isna().sum()
# Out:
# batting_team       0
# bowling_team       0
# city            6012
# runs_left          0
# total_runs_x       0
# balls_left         0
# wickets_left       0
# crr                0
# rrr               12
# result             0
# dtype: int64

# %%
final_df.dropna()
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  total_runs_x  balls_left  wickets_left        crr  \
# ...

# %%
final_df.describe()
# Out:
#            runs_left   total_runs_x     balls_left   wickets_left  \
# count  111082.000000  111082.000000  111082.000000  111082.000000
# mean       93.714049     168.226463      62.689797       7.507229
# std        50.900767      30.489285      33.466373       2.167296
# min       -16.000000      62.000000      -3.000000       0.000000
# 25%        54.000000     148.000000      35.000000       6.000000
# 50%        93.000000     168.000000      63.000000       8.000000
# 75%       132.000000     188.000000      92.000000       9.000000
# max       277.000000     277.000000     119.000000      10.000000
#
#                  crr           rrr         result
# count  111082.000000  1.110700e+05  111082.000000
# mean        7.573222           NaN       0.513468
# std         2.340490           NaN       0.499821
# min         0.000000          -inf       0.000000
# 25%         6.378947  7.200000e+00       0.000000
# 50%         7.600000  9.000000e+00       1.000000
# ...

# %%
final_df=final_df[final_df['balls_left']!=0]

# %%
final_df.shape
# Out:
# (110698, 10)

# %%
final_df.isna().sum()
# Out:
# batting_team       0
# bowling_team       0
# city            5990
# runs_left          0
# total_runs_x       0
# balls_left         0
# wickets_left       0
# crr                0
# rrr                0
# result             0
# dtype: int64

# %%
final_df.dropna(inplace=True)
# Out:
# C:\Users\Kale Ji\AppData\Local\Temp\ipykernel_6344\2709626079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df.shape
# Out:
# (104708, 10)

# %%
len(final_df['result'])
# Out:
# 104708

# %%
y=final_df['result']
X=final_df.drop(['result'],axis='columns')

# %%
X_train.describe()
# Out:
#           runs_left  total_runs_x    balls_left  wickets_left           crr  \
# count  83766.000000  83766.000000  83766.000000  83766.000000  83766.000000
# mean      93.772688    168.207101     62.869553      7.519005      7.596584
# std       50.777291     30.548788     33.342028      2.149288      2.353791
# min      -16.000000     62.000000     -3.000000      0.000000      0.000000
# 25%       54.000000    148.000000     35.000000      6.000000      6.393443
# 50%       93.000000    168.000000     64.000000      8.000000      7.615385
# 75%      131.000000    188.000000     92.000000      9.000000      8.857143
# max      277.000000    277.000000    119.000000     10.000000     36.000000
#
#                 rrr
# count  83766.000000
# mean      10.495044
# std       13.661457
# min     -510.000000
# 25%        7.212121
# 50%        8.963855
# 75%       11.110561
# max      708.000000

# %%
X_train.shape
# Out:
# (83766, 9)

# %%
X_test.shape
# Out:
# (20942, 9)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
trf=ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')

# %%
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression())
])

# %%
pipe
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression())])

# %%
pipe.fit(X_train,y_train)
# Out:
# D:\PYTHON CODES\Anaconda System\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# D:\PYTHON CODES\Anaconda System\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
# ...

# %%
pipe.score(X_test,y_test)
# Out:
# 0.7982045649890173

# %%
y_pred=pipe.predict(X_test)

# %%
y_test[:5]
# Out:
# 208873    1
# 215591    1
# 205899    1
# 85182     0
# 130212    1
# Name: result, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.7982045649890173

# %%
from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(y_pred,y_test)
print(matrix)
# Out:
# [[7775 2002]
#  [2224 8941]]

# %%
pipe.predict_proba(X_test)[0]
# Out:
# array([0.90095873, 0.09904127])

# %%
teams
# Out:
# ['Mumbai Indians',
#  'Chennai Super Kings',
#  'Royal Challengers Bangalore',
#  'Rajasthan Royals',
#  'Sunrisers Hyderabad',
#  'Gujarat Titans',
#  'Lucknow Super Giants',
#  'Delhi Capitals',
#  'Punjab Kings',
#  'Kolkata Knight Riders']

# %%
final_df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi',
#        'Bengaluru', 'Indore', 'Dubai', 'Sharjah', 'Navi Mumbai',
#        'Lucknow', 'Guwahati', 'Mohali'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
